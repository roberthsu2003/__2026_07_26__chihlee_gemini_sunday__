# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，主要是因為**太陽光**與**地球大氣層**之間產生的一種物理現象，科學上稱為**「瑞利散射」（Rayleigh scattering）**。
#
# 我們可以把這個過程拆解成三個簡單的步驟來理解：
#
# ### 1. 太陽光其實是「彩虹色」的
# 雖然太陽光看起來是白色的，但它其實是由紅、橙、黃、綠、藍、靛、紫等所有彩虹的顏色混合而成的。這些光以「波」的形式傳播：
# *   **紅光、橙光**：波長較**長**。
# *   **藍光、紫光**：波長較**短**。
#
# ### 2. 大氣層的「阻擋」與「散射」
# 當太陽光穿過地球的大氣層時，會撞擊到大氣中的氣體分子（主要是氮氣和氧氣）。
# 根據物理定律，**波長較短的光（藍光和紫光）遇到這些微小分子時，特別容易被反彈、往四面八方散射開來**；而波長較長的光（紅光、黃光）則像沒事一樣，直接穿透大氣層直達地面。
#
# 因為藍光在天空中被無數次地「折騰」並折射到我們的眼睛裡，所以我們抬頭看天空時，到處都是被散射的藍光。
#
# ### 3. 為什麼天空不是「紫色」的？
# 既然紫光的波長比藍光更短，理論上紫光的散射應該更嚴重，那為什麼天空不是紫色的呢？這有兩個主要原因：
# 1.  **太陽光的成分**：太陽放射出的光芒中，藍光的比例本來就比紫光多得多。
# 2.  **人類眼睛的構造**：人類的眼睛對「藍色」比對「紫色」敏感得多。我們的視網膜接收到藍光和微量紫光的混合後，大腦會自動將它解讀為我們看見的「天藍色」。
#
# ---
#
# ### 💡 順帶一提：那為什麼夕陽是紅色的？
# 在清晨或黃昏時，太陽角度很低，陽光必須穿過**比中午厚很多**的大氣層才能到達我們的眼睛。
# 在這個漫長的過程中，大部分的藍光在半路就已經被散射光了，只剩下波長最長、穿透力最強的**紅光、橙光**能成功到達我們的眼睛，所以夕陽看起來就是美麗的橘紅色了！
