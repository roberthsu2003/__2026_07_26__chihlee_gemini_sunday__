# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以呈現藍色，主要是因為**太陽光**與**地球大氣層**相互作用所產生的現象，這個物理原理被稱為**「瑞利散射」（Rayleigh scattering）**。
#
# 我們可以把這個過程拆解成三個簡單的步驟來理解：
#
# ### 1. 太陽光是由「彩虹七色」組成的
# 雖然太陽光看起來是白色的，但它其實包含了紅、橙、黃、綠、藍、靛、紫等所有顏色的光。這些光以「波」的形式傳播，而不同顏色的光，**波長**也不同：
# *   **紅光、黃光**：波長較**長**（像溫和的大浪）。
# *   **藍光、紫光**：波長較**短**（像急促的小浪）。
#
# ### 2. 大氣層中的「阻礙物」
# 地球周圍包圍著厚厚的大氣層，裡面充滿了氣體分子（主要是氮氣和氧氣）。當太陽光穿過大氣層時，就會撞擊到這些微小的氣體分子。
#
# ### 3. 「瑞利散射」發生了
# 當光線撞擊到比自己波長還要小的氣體分子時，就會發生散射（向四面八方彈射）：
# *   波長較長的**紅光、黃光**，很容易穿透這些微小的氣體分子，直接照射到地面。
# *   波長較短的**藍光、紫光**，撞到氣體分子時會被**瘋狂地向四面八方散射**。當我們抬頭看天空時，這些被散射到整個天空的藍光進入我們的眼睛，天空看起來就是藍色的了。
#
# ---
#
# ### 💡 常見的兩個小迷思：
#
# *   **問題一：既然紫光的波長比藍光更短、散射更嚴重，為什麼天空不是紫色的？**
#     這有兩個原因：
#     1.  **太陽的因素**：太陽放射出的光芒中，藍光的比例本來就比紫光多很多。
#     2.  **眼睛的因素**：人類的眼睛對「藍色」比對「紫色」敏感得多。所以即使天空中有紫光，我們的眼睛大腦也會自動把視覺信號處理成藍色。
#
# *   **問題二：為什麼傍晚的夕陽是紅色的？**
#     黃昏時，太陽角度很低，陽光必須穿過**比中午厚很多**的大氣層才能到達我們的眼睛。在這個過程中，藍光在半路就已經被散射光了，只剩下波長最長、穿透力最強的紅光和橙光能夠到達我們的眼睛，所以夕陽看起來是紅橘色的。
