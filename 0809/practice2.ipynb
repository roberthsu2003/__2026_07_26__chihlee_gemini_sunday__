# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，主要是因為**太陽光**、**地球大氣層**以及一種物理現象——「**瑞利散射**」（Rayleigh scattering）共同作用的結果。
#
# 我們可以把這個過程拆解成三個簡單的步驟來理解：
#
# ### 1. 太陽光其實是「彩虹色」的
# 雖然太陽光看起來是白色的，但它其實包含了紅、橙、黃、綠、藍、靛、紫等所有顏色的光。這些光以「波」的形式傳播，不同顏色的光波長不同：
# *   **紅色、橙色光**：波長較**長**。
# *   **藍色、紫色光**：波長較**短**。
#
# ### 2. 大氣層的「阻擋」與「散射」
# 地球周圍包圍著厚厚的大氣層，裡面充滿了氮氣、氧氣等氣體分子。
# 當太陽光穿過大氣層時，會與這些微小的氣體分子碰撞：
# *   波長較長的光（如紅光、黃光）像大卡車一樣，能夠輕易穿過這些微小的氣體分子，直接照射到地面。
# *   波長較短的光（如藍光、紫光）就像小乒乓球一樣，撞到氣體分子後，就會**向四面八方彈射開來**。這種現象在物理學上稱為「**瑞利散射**」。這些被撞得滿天飛的藍色光填滿了天空，當我們抬頭看時，就會覺得天空是藍色的。
#
# ### 3. 為什麼天空不是「紫色」的？
# 這是一個很好的問題！既然紫光的波長比藍光更短，理論上紫光的散射應該更嚴重，天空為什麼不是紫色的呢？原因有兩個：
# 1.  **太陽光的成分**：太陽光中本來就是藍光多於紫光。
# 2.  **人類眼睛的構造**：人類眼睛的視網膜上有感知顏色的錐狀細胞，我們對「藍色」的敏感度遠遠高於「紫色」。因此，即使天空中有一些紫光，我們的眼睛和眼睛的大腦處理後，看到的依然是美麗的藍天。
#
# ---
#
# ### 補充小知識：那為什麼傍晚的夕陽是紅色的？
# 到了黃昏時，太陽落到地平線附近，陽光需要穿過**比中午厚很多**的大氣層才能到達我們的眼睛。
# 在這段長途旅行中，絕大多數的藍光在半路就已經被散射光了，只剩下穿透力最強的**紅光和橙光**能夠到達我們的眼睛，所以夕陽和晚霞才會呈現美麗的橙紅色。
