# %%
x = 7
print(x == 5)
print(x == 7)
print(5 < x)
# Out:
# False
# True
# True

# %%
print("Hello! World")
# Out:
# Hello! World

# %%
a = 13
if a != 12:
    print("不等於12")
else:
    print("等於12")
# Out:
# 不等於12
